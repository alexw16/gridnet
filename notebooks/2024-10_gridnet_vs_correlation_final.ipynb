# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

import csv
# import umap
import scanpy as sc

def corr2_coeff(A, B):
    # Rowwise mean of input arrays & subtract from input arrays themeselves
    A_mA = A - A.mean(1)[:, None]
    B_mB = B - B.mean(1)[:, None]

    # Sum of squares across rows
    ssA = (A_mA**2).sum(1)
    ssB = (B_mB**2).sum(1)

    # Finally get corr coeff
    return np.dot(A_mA, B_mB.T) / np.sqrt(np.dot(ssA[:, None],ssB[None]))

# %%
import h5py
from scipy.sparse import csr_matrix

def load_data(dataset,gene_percent_cells=0.01,peak_percent_cells=0.001,include_h5=True,
              preprocess=True,sampling=None,distance=1000000):
    
    data_dir = '/data/cb/alexwu/mm_finemap/datasets/{}'.format(dataset)

    if sampling == 'geosketch':
        rna_adata = sc.read(os.path.join(data_dir,'{}.rna.sketch.h5ad'.format(dataset)))
        atac_adata = sc.read(os.path.join(data_dir,'{}.atac.sketch.h5ad'.format(dataset)))
    elif sampling == 'uniform':
        rna_adata = sc.read(os.path.join(data_dir,'{}.rna.uniform.h5ad'.format(dataset)))
        atac_adata = sc.read(os.path.join(data_dir,'{}.atac.uniform.h5ad'.format(dataset)))        
    else:
        rna_adata = sc.read(os.path.join(data_dir,'{}.rna.h5ad'.format(dataset)))
        atac_adata = sc.read(os.path.join(data_dir,'{}.atac.h5ad'.format(dataset)))

    if dataset == 'sci_car':
        data_dir = '/data/cb/alexwu/mm_finemap/data/sci_car'
        adata = sc.read(os.path.join(data_dir,'adata-hs.h5ad'))

        atac_adata.var['chr_no'] = ['chr' + n for n in atac_adata.var['chr_no']]
        atac_adata.var['start'] = adata.uns['atac.var'][:,2].astype(int)
        atac_adata.var['end'] = adata.uns['atac.var'][:,3].astype(int)

    if preprocess:
        # scale by maximum 
        # (rna already normalized by library size + log-transformed)
        X_max = rna_adata.X.max(0).toarray().squeeze()
        X_max[X_max == 0] = 1
        rna_adata.X = csr_matrix(rna_adata.X / X_max)

        # atac: normalize library size + log transformation
        sc.pp.normalize_total(atac_adata,target_sum=1e4)
        sc.pp.log1p(atac_adata)

    if include_h5:
        data_dir = '/data/cb/alexwu/mm_finemap/datasets/{}'.format(dataset)
        with h5py.File(os.path.join(data_dir,'dataset.h5'),'r') as f:
            print(f.keys())
            data_df = pd.DataFrame()
            for k in ['chr_no','eqtl','hic','dist','atac_id','gene','corr','group_corr','gene_percent_cells',
                      'peak_percent_cells','hg38tohg19_eqtl','eqtl.new','corr_bin','group_corr_bin',
                      'hic_0hr','hic_1hr','hic_4hr','eqtl.q','hic_4hr.expectedBL','eqtl.all','hic.new2',
                      'hic.100kb','ABC.score'] + ['placseq_{}'.format(c) for c in ['eN','iN','IPC','RG']]: #,
#                      'hic_0hr.expectedBL','hic_1hr.expectedBL','hic_4hr.expectedBL.new','hic_0hr.expectedBL.new',
#                      'hic_4hr.expectedBL.new2','hic_12hr.expectedBL','hic_4hr.expectedBL.full']:
                if k in f.keys():
                    data_df[k] = f[k][:]

        small_df = data_df[abs(data_df['dist']) < distance]

        # small_df = small_df[~np.isnan(small_df['group_corr'])]
        small_df = small_df[small_df['gene_percent_cells'] > gene_percent_cells]
        small_df = small_df[small_df['peak_percent_cells'] > peak_percent_cells]

        small_df.index = [(atac_idx,gene) for atac_idx,gene in small_df[['atac_id','gene']].values]
    
        return rna_adata,atac_adata,small_df

    else:
        
        return rna_adata,atac_adata

# %%
['placseq_{}'.format(c) for c in ['eN','iN','IPC','RG']]

'''
eN: excitatory neurons
iN: interneurons
IPC: intermediate progenitor cells
RG: radial glia
'''
# Out:
# '\neN: excitatory neurons\niN: interneurons\nIPC: intermediate progenitor cells\nRG: radial glia\n'

# %%
from scipy.stats import rankdata

def load_results(dataset,eval_df,ensemble=False,gene_percent_cells=0.01,peak_percent_cells=0.001):
    
    n_layers = 10
    n_neighbors = 15
    mode = 'lr'

    eval_df['ABC.score'] = eval_df['ABC.score'].replace(np.nan, 0)
    eval_df['ABC.score'] = eval_df['ABC.score'].values #.astype(bool).astype(float)

    eval_df['corr'] = eval_df['corr'].replace(np.nan, 0)
    eval_df['group_corr'] = eval_df['group_corr'].replace(np.nan, 0)

    data_dir = '/data/cb/alexwu/mm_finemap/results/tests_nn/{}'.format(dataset)

    
    if dataset in ['sci_car','snare_seq']:
        
        method = 'graph'
        data_dir = '/data/cb/alexwu/mm_finemap/results/tests_nn/{}'.format(dataset)
        for trial_no in range(1,6):

            file_name = 'graph.trial{}.all.max_scale.mseloss.{}layers.nn{}.statistics.txt'.format(trial_no,n_layers,n_neighbors)
            scores = pd.read_csv(os.path.join(data_dir,file_name),sep='\t').values[:,2].astype(float)
            scores[np.isinf(scores)] = 10**10
            eval_df['{}.trial{}'.format(method,trial_no)] = scores
            
    elif dataset in ['share_seq_more','human_cortex_multiome_lineage']:
        
        method = 'graph'
        for trial_no in range(1,6):

            if trial_no == 1:
                data_dir = '/data/cb/alexwu/mm_finemap/results/tests_nn/{}'.format(dataset)
            else:
                data_dir = '/data/cb/alexwu/mm_finemap/results/tests_nn/{}_{}'.format(dataset,trial_no)

            if dataset == 'human_cortex_multiome_lineage':
                file_name = 'graph.uniform.250kb.trial{}.all.max_scale.mseloss.{}layers.nn{}.statistics.txt'.format(trial_no,n_layers,n_neighbors)
            elif dataset == 'share_seq_more':
                file_name = 'graph.uniform.trial{}.all.max_scale.mseloss.{}layers.nn{}.statistics.txt'.format(trial_no,n_layers,n_neighbors)
            else:
                file_name = 'graph.uniform.trial{}.all.max_scale.mseloss.{}layers.nn{}.statistics.txt'.format(trial_no,n_layers,n_neighbors)

            scores = pd.read_csv(os.path.join(data_dir,file_name),sep='\t').values[:,2].astype(float)
            scores[np.isinf(scores)] = 10**10
            eval_df['{}.trial{}'.format(method,trial_no)] = scores
            
        
            if trial_no == 1:
                data_dir = '/data/cb/alexwu/mm_finemap/datasets/{}'.format(dataset)
            else:
                data_dir = '/data/cb/alexwu/mm_finemap/datasets/{}_{}'.format(dataset,trial_no)

            # correlations
            with h5py.File(os.path.join(data_dir,'dataset.h5'),'r') as f:
                data_df = pd.DataFrame()
                for k in ['dist','corr','group_corr','gene_percent_cells','peak_percent_cells']:
                    if k in f.keys():
                        data_df[k] = f[k][:]

            small_df = data_df[abs(data_df['dist']) < distance]

            # small_df = small_df[~np.isnan(small_df['group_corr'])]
            small_df = small_df[small_df['gene_percent_cells'] > gene_percent_cells]
            small_df = small_df[small_df['peak_percent_cells'] > peak_percent_cells]

            eval_df['corr.trial{}'.format(trial_no)] = small_df['corr'].replace(np.nan, 0).values
            eval_df['group_corr.trial{}'.format(trial_no)] = small_df['group_corr'].replace(np.nan, 0).values

    if ensemble:
                
        for method in ['graph','corr','group_corr']:
            eval_df['{}.ranks.mean'.format(method)] = np.array([rankdata(abs(eval_df['{}.trial{}'.format(method,trial_no)].values),
                                                                method='average') for trial_no in range(1,6)]).mean(0)

#         distance_ranks = rankdata(-abs(eval_df['dist'].values),method='average')
#         eval_df['dist_ranks'] = distance_ranks

#         for feature in ['graph.ranks.mean','group_corr.ranks.mean','corr.ranks.mean']:
#             eval_df[feature + '-dist'] = (distance_ranks + eval_df[feature].values)/2
            
    return eval_df

# %%
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

def get_results(dataset,method,n_layers=None,n_neighbors=None,mode=None,sketch=False,trial_no=None,new=True):
    
    data_dir = '/data/cb/alexwu/mm_finemap/results/tests_nn/{}'.format(dataset)
    
    if method == 'graph':
        trial_str = 'new2' if trial_no == 0 else 'trial{}'.format(trial_no)
        if sketch:
            file_name = 'graph.sketch.{}.all.max_scale.mseloss.{}layers.nn{}.{}.p.txt'.format(trial_str,n_layers,n_neighbors,mode)
        else:
            file_name = 'graph.{}.all.max_scale.mseloss.{}layers.nn{}.{}.p.txt'.format(trial_str,n_layers,n_neighbors,mode)
    elif method == 'granger':
        if sketch:
            file_name = 'baseline.bin.sketch.bin.results.txt'
        else:
            file_name = 'baseline.bin.bin.results.txt'
    elif method == 'graph.base':
        if sketch:
            file_name = 'graph.base.sketch.new.{}layers.nn{}.{}.txt'.format(n_layers,n_neighbors,mode)
        else:
            file_name = 'graph.base.new.{}layers.nn{}.{}.txt'.format(n_layers,n_neighbors,mode)
            
    elif method == 'gvar':
        if sketch:
            file_name = 'gvar.bin.sketch.trial{}.results.txt'.format(trial_no)
        else:
            file_name = 'gvar.bin.trial{}.bin.results.txt'.format(trial_no)

    elif method == 'GVAR':
        if sketch:
            file_name = 'GVAR.bin.sketch.trial{}.bin.results.txt'.format(trial_no)
        else:
            file_name = 'GVAR.bin.trial{}.bin.results.txt'.format(trial_no)
            
    scores = pd.read_csv(os.path.join(data_dir,file_name),header=None).values
    if scores.shape[1] > 1:
        scores = scores[:,2]
    
    if (method == 'graph' and mode == 'lr') or method == 'gvar':
        return scores
    else:
        scores[scores == 0] = 10**-100
        scores = -np.log10(scores)
        return scores

def print_results(eval_df,method_list,feature,thresh,direction,metric='auprc'):
    
    if direction == 'less':
        y_true = eval_df[feature].values <= thresh
    elif direction == 'greater':
        y_true = eval_df[feature].values >= thresh

#     print('\nBASELINE:',y_true.mean(),'----------\n')

    data_dict = {'method': [], metric: []}
    for method in method_list:
        scores = abs(eval_df[method].values)
#         if 'corr' in method:
#             scores = abs(scores)
#         elif 'dist' in method:
#             scores = -abs(scores)
                
        if metric == 'auprc':
            value = average_precision_score(y_true,scores)
        elif metric == 'auroc':
            value = roc_auc_score(y_true,scores)
#         elif metric == 'f1':
#             scores = (scores > np.percentile(scores,99)).astype(int)
#             value = f1_score(y_true,scores)
            
        auprc = average_precision_score(y_true,scores)
        data_dict['method'].append(method)
        data_dict[metric].append(value)

    results_df = pd.DataFrame(data_dict)
    results_df['trial_no'] = [int(n.split('trial')[1]) if 'trial' in n else 0 for n in results_df['method']]
    results_df['method'] = [n.split('.trial')[0] for n in results_df['method']]
    
    return results_df

def get_precision_recall(eval_df,method,feature,percentile,direction):
    
    scores_list = []
    y_true_list = []
    for chr_no in sorted(list(set(eval_df['chr_no'].values))):
        
        chr_df = eval_df[eval_df['chr_no'] == chr_no]

        thresh = np.percentile(chr_df[feature].values,percentile)
        
        if direction == 'less':
            y_true = abs(chr_df[feature].values) <= thresh
        elif direction == 'greater':
            y_true = abs(chr_df[feature].values) >= thresh
            
        y_true_list.extend(y_true.astype(int).tolist())
        scores_list.extend(chr_df[method].values.tolist())
    
    y_true = np.array(y_true_list)
    
    scores = np.array(scores_list)
    if 'corr' in method:
        scores = abs(scores)
    elif 'dist' in method:
        scores = -abs(scores)

    precision, recall, thresholds = precision_recall_curve(y_true,scores)
    return precision, recall, thresholds

# %%
import math

def round_sigfigs(number,significant_digits=3):
    return round(number, significant_digits - int(math.floor(math.log10(abs(number)))) - 1)

def num_sigfigs(number):
    return len(str(number).split('.')[1].strip('0'))
    
def create_plot(results_df,metric):
    
    plt.figure(figsize=(len(set(results_df['method']))/2,5))
    sns.barplot(x='method',y=metric,hue='method',data=results_df,capsize=0.1,dodge=False)
    plt.ylim(0,results_df[metric].max()*1.02)
    plt.xlabel('',fontsize=16)
    plt.ylabel(metric.upper(),fontsize=16)
    plt.yticks(fontsize=14)
    plt.xticks(rotation=90)

# %%
from scipy.stats import f
from statsmodels.stats.multitest import fdrcorrection

def lr_ftest(lr,n_layers,n):
    
    # number of reduced model parameters (W,b for each RNA layer)
    p1 = n_layers * 2 
    # number of full model parameters (W,b for each layer of RNA, ATAC + interaction)
    p2 = n_layers * 2 * 2 + 1 
    
    dfn = 2 * n_layers + 1
    dfd = n - 4 * n_layers - 1

    F = (lr - 1) * (n - p2)/(p2-p1)

    return 1-f.cdf(F,dfn,dfd)

def calculate_fdr(p):
    
    return fdrcorrection(p)[1]

# %%
def calculate_correlations(data_df,rna_adata,atac_adata,corr_key):
    
    if 'atac_idx' in data_df.keys() and 'atac_id' not in data_df.keys():
        data_df['atac_id'] = data_df['atac_idx'].values
        
    corr_dict = {}
    for chr_no in sorted(list(set(data_df['chr_no'].values))):
        print(chr_no)
        filtered_data_df = data_df[data_df['chr_no'] == chr_no]

        gene_inds = sorted(list(set(filtered_data_df['gene'].values)))
        atac_inds = list(map(str,sorted(list(set(filtered_data_df['atac_id'].values)))))

        filtered_rna_X = rna_adata[:,gene_inds].X.toarray()
        filtered_atac_X = atac_adata[:,atac_inds].X.toarray()

        rho = corr2_coeff(filtered_rna_X.T,filtered_atac_X.T)
        df = pd.DataFrame(rho,index=gene_inds,columns=atac_inds)
        print(df)

        for gene,atac_idx in filtered_data_df[['gene','atac_id']].values:
            corr_dict[(gene,atac_idx)] = df.loc[gene,str(atac_idx)]
            
    corr_list = []
    for gene,atac_idx in data_df[['gene','atac_id']].values:
        corr_list.append(corr_dict[(gene,atac_idx)])

    data_df[corr_key] = corr_list

    return data_df

def create_metacells(rna_adata,atac_adata):
    
    group_rna_X = []
    group_atac_X = []
    rna_X = rna_adata.X.toarray()
    rna_X = (((np.exp(rna_X)-1)/1e5).T*rna_adata.obs['n_counts'].values).T # raw counts

    for i in range(rna_adata.shape[0]):
        inds = np.nonzero(rna_adata.obsp['distances'][i])[1]
        inds = np.array(list(inds) + [i])
        group_rna_X.append(rna_X[inds].sum(0))
        group_atac_X.append(atac_adata[inds].X.sum(0))

        if i % 1000 == 0:
            print(i)

    group_rna_X = np.array(group_rna_X).squeeze()
    group_atac_X = np.array(group_atac_X).squeeze()
    
    group_rna_adata = rna_adata.copy()
    group_atac_adata = atac_adata.copy()

    group_rna_adata.X = group_rna_X #.copy()
    group_atac_adata.X = group_atac_X #.copy()
    
    sc.pp.normalize_total(group_rna_adata,target_sum=1e5)
    sc.pp.log1p(group_rna_adata)

    sc.pp.normalize_total(group_atac_adata,target_sum=1e4)
    sc.pp.log1p(group_atac_adata)
    
    return group_rna_adata,group_atac_adata

def perform_correlation_calculations(data_df,rna_adata,atac_adata,dataset,mode):
    
    rna_adata_copy = rna_adata.copy()
    atac_adata_copy = atac_adata.copy()
    
    if mode == 'corr':
        sc.pp.normalize_total(atac_adata_copy,target_sum=1e4)
        sc.pp.log1p(atac_adata_copy)
        
    elif mode == 'group_corr':
        sc.pp.neighbors(rna_adata_copy,use_rep='X_schema',n_neighbors=50)
        rna_adata_copy,atac_adata_copy = create_metacells(rna_adata_copy,atac_adata_copy)

    corr_key = mode
    data_df = calculate_correlations(data_df,rna_adata_copy,atac_adata_copy,corr_key)

    save_dir = '/data/cb/alexwu/mm_finemap/datasets/{}'.format(dataset)

    with h5py.File(os.path.join(save_dir,'dataset.h5'),'a') as f:
        if corr_key in f.keys():
            del f[corr_key]
        f.create_dataset(corr_key,data=data_df[corr_key].values,dtype=float)

# %%
def convert_name(n):
    
    if 'graph' in n:
        name = 'GrID-Net'
    elif 'group' in n:
        name = 'Pseudocell Corr'
    elif 'corr' in n:
        name = 'Correlation'
    elif 'ABC' in n:
        name = 'ABC'
    
    if 'ranks' in n:
        name += ' (ens)'
        
    if 'rra' in n:
        name += ' (RRA)'
    
    if '-dist' in n:
        name += ' (dist)'
        
    return name

# %% [markdown]
# ## Results

# %%
dataset = 'human_cortex_multiome_lineage'

sampling = 'uniform' if dataset in ['share_seq_more','human_cortex_multiome_lineage'] else None
distance = 250000 if dataset in ['human_cortex_multiome_lineage'] else 1000000

rna_adata,atac_adata,eval_df = load_data(dataset,sampling=sampling,gene_percent_cells=0.01,
                                          peak_percent_cells=0.001,include_h5=True,
                                          distance=distance,preprocess=False)

eval_df = load_results(dataset,eval_df,ensemble=True)
# Out:
# WARNING: Your filename has more than two extensions: ['.rna', '.uniform', '.h5ad'].
# Only considering the two last: ['.uniform', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.rna', '.uniform', '.h5ad'].
# Only considering the two last: ['.uniform', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.atac', '.uniform', '.h5ad'].
# Only considering the two last: ['.uniform', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.atac', '.uniform', '.h5ad'].
# Only considering the two last: ['.uniform', '.h5ad'].
# <KeysViewHDF5 ['ABC.score', 'atac_id', 'chr_no', 'corr', 'dist', 'eqtl.all', 'eqtl.fdr', 'eqtl.gtex', 'gene', 'gene_percent_cells', 'group_corr', 'hic', 'hic.new', 'peak_percent_cells', 'placseq_IPC', 'placseq_RG', 'placseq_eN', 'placseq_iN']>

# %% [markdown]
# ## GrID-Net vs. Correlation

# %%
eval_df['corr_diff'] = eval_df['graph.ranks.mean'].values-eval_df['corr.ranks.mean'].values
eval_df['group_corr_diff'] = eval_df['graph.ranks.mean'].values-eval_df['group_corr.ranks.mean'].values

for trial_no in range(1,6):
    eval_df['corr_diff.{}'.format(trial_no)] = eval_df['graph.trial{}'.format(trial_no)].values-eval_df['corr.trial{}'.format(trial_no)].values
    eval_df['group_corr_diff.{}'.format(trial_no)] = eval_df['graph.trial{}'.format(trial_no)].values-eval_df['group_corr.trial{}'.format(trial_no)].values

# # top peak-gene pairs + peaks in 5+% of cells
# thresh = np.percentile(eval_df['graph.ranks.mean'],90)
# filtered_eval_df = eval_df[(eval_df['graph.ranks.mean'] > thresh)] # & (eval_df['peak_percent_cells'] > 0.001)]

# corr_diff_pairs = filtered_eval_df.sort_values('corr_diff',ascending=False).index.values[0:100000]
# group_corr_diff_pairs = filtered_eval_df.sort_values('group_corr_diff',ascending=False).index.values[0:100000]

# %% [markdown]
# ### Histone Marks

# %%
save_dir = '/data/cb/alexwu/mm_finemap/results/chip_seq/{}'.format(dataset)

chip_atac_id_dict = {}
for score_thresh in [50,100,200]: #,500]: # motif score
    for chip_type in ['h3k27ac','h3k4me1']:
        print(chip_type)
        
        file_name = "intersect.{}.{}.score{}.bed".format(dataset,chip_type,score_thresh)

        overlap_df = pd.read_csv(os.path.join(save_dir,file_name),sep='\t',header=None)
        overlap_df.columns = ['chr_no','overlap_start','overlap_end','atac_id']
        chip_atac_id_dict[(chip_type,score_thresh)] = overlap_df['atac_id'].values
        
    chip_atac_id_dict[(chip_type,score_thresh)] = overlap_df['atac_id'].values
    
    # active enhancers
    file_name = "intersect.{}.{}.score{}.bed".format(dataset,'active_enhancers',score_thresh)

    overlap_df = pd.read_csv(os.path.join(save_dir,file_name),sep='\t',header=None)
    overlap_df.columns = ['chr_no','overlap_start','overlap_end','atac_id']
    chip_atac_id_dict[('active_enhancers',score_thresh)] = overlap_df['atac_id'].values
# Out:
# h3k27ac
# h3k4me1
# h3k27ac
# h3k4me1
# h3k27ac
# h3k4me1

# %%
# eval_df['corr_diff'] = eval_df['graph.ranks.mean']-eval_df['corr.ranks.mean']
# eval_df['group_corr_diff'] = eval_df['graph.ranks.mean']-eval_df['group_corr.ranks.mean']

score_thresh = 200
results_dict = {k: [] for k in ['method','placement','ratio']}
for compare_key in ['corr_diff','group_corr_diff']: # ["{}.{}".format(m,trial_no) for m in ['corr_diff','group_corr_diff'] for trial_no in range(1,6)]:

    thresh = np.percentile(eval_df[compare_key],99)
    diff_top_atac_id = set(eval_df[(eval_df[compare_key] > thresh)]['atac_id'])
    thresh = np.percentile(eval_df[compare_key],1)
    diff_bottom_atac_id = set(eval_df[(eval_df[compare_key] < thresh)]['atac_id'])
    
    all_atac_id = set(eval_df['atac_id'])

    h3k27ac_atac_ids = set(chip_atac_id_dict[('h3k27ac',score_thresh)])
    h3k4me1_atac_ids = set(chip_atac_id_dict[('h3k4me1',score_thresh)])
    active_enhancer_atac_ids = set(chip_atac_id_dict[('active_enhancers',score_thresh)])
    
    for placement,atac_ids in zip(*[['top','bottom','all'],[diff_top_atac_id,diff_bottom_atac_id,all_atac_id]]):
        
        h3k27ac_overlaps = h3k27ac_atac_ids & atac_ids
        h3k4me1_overlaps = h3k4me1_atac_ids & atac_ids

        n_poised = h3k4me1_overlaps - h3k27ac_overlaps
        n_active = active_enhancer_atac_ids & atac_ids #h3k4me1_overlaps & h3k27ac_overlaps
    
#         print(compare_key,placement,len(n_poised)/len(n_active))
        
        results_dict['method'].append(compare_key.split(".")[0])
        results_dict['placement'].append(placement)
        results_dict['ratio'].append(len(n_poised)/len(n_active))
    
results_df = pd.DataFrame(results_dict)

all_ratio = results_df[results_df['placement'] == 'all']['ratio'].values[0]

results_df = results_df[results_df['placement'] != 'all']

# results_df['placement'] = ['{} 1% Peak-Gene Pairs'.format(n.capitalize()) if n != 'all' else n for n in results_df['placement']]
results_df['placement'] = ['GrID-Net' if n == 'top' else 'Corr-Based Method' for n in results_df['placement']]

results_df['placement'] = [n if n != 'all' else 'All Peak-Gene Pairs' for n in results_df['placement']]
results_df['method'] = ['GrID-Net\nvs.\n{}'.format(convert_name(n)) for n in results_df['method']]

plt.figure(figsize=(4.5,4))
g = sns.barplot(x='method',y='ratio',hue='placement',data=results_df,palette='Paired')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('',fontsize=16)
plt.ylabel('Poised:Active\nEnhancer Ratio',fontsize=20)
plt.legend(title='Peak-Gene Pairs Prioritized by',title_fontsize=18,fontsize=16,frameon=False,bbox_to_anchor=(1,1),handlelength=0.8)
# g.axhline(y=all_ratio,linestyle='--',color='black',linewidth=3)
sns.despine()

plot_dir = '/data/cb/alexwu/mm_finemap/figures'
# plt.savefig(os.path.join(plot_dir,'gridnet_vs_corr','poised_vs_active.png'.format(dataset)), dpi=500, bbox_inches = "tight")
plt.show()

# %%
results_df
# Out:
#                            method          placement     ratio
# 0      GrID-Net\nvs.\nCorrelation           GrID-Net  0.295983
# 1      GrID-Net\nvs.\nCorrelation  Corr-Based Method  0.189931
# 3  GrID-Net\nvs.\nPseudocell Corr           GrID-Net  0.264753
# 4  GrID-Net\nvs.\nPseudocell Corr  Corr-Based Method  0.208602

# %%
results_df
# Out:
#                             method          placement     ratio
# 0       GrID-Net\nvs.\nCorrelation           GrID-Net  0.159281
# 1       GrID-Net\nvs.\nCorrelation  Corr-Based Method  0.250896
# 3       GrID-Net\nvs.\nCorrelation           GrID-Net  0.146746
# 4       GrID-Net\nvs.\nCorrelation  Corr-Based Method  0.295533
# 6       GrID-Net\nvs.\nCorrelation           GrID-Net  0.193299
# 7       GrID-Net\nvs.\nCorrelation  Corr-Based Method  0.261538
# 9       GrID-Net\nvs.\nCorrelation           GrID-Net  0.167759
# 10      GrID-Net\nvs.\nCorrelation  Corr-Based Method  0.293706
# 12      GrID-Net\nvs.\nCorrelation           GrID-Net  0.184246
# 13      GrID-Net\nvs.\nCorrelation  Corr-Based Method  0.273063
# 15  GrID-Net\nvs.\nPseudocell Corr           GrID-Net  0.217391
# 16  GrID-Net\nvs.\nPseudocell Corr  Corr-Based Method  0.169192
# 18  GrID-Net\nvs.\nPseudocell Corr           GrID-Net  0.228438
# 19  GrID-Net\nvs.\nPseudocell Corr  Corr-Based Method  0.168342
# 21  GrID-Net\nvs.\nPseudocell Corr           GrID-Net  0.246341
# 22  GrID-Net\nvs.\nPseudocell Corr  Corr-Based Method  0.194103
# 24  GrID-Net\nvs.\nPseudocell Corr           GrID-Net  0.207048
# 25  GrID-Net\nvs.\nPseudocell Corr  Corr-Based Method  0.150990
# 27  GrID-Net\nvs.\nPseudocell Corr           GrID-Net  0.203991
# 28  GrID-Net\nvs.\nPseudocell Corr  Corr-Based Method  0.161954

# %%
plt.figure(figsize=(1.7,3))
g = sns.barplot(x='placement',y='ratio',data=results_df[results_df["method"] == "GrID-Net\nvs.\nCorrelation"],palette='Paired')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.locator_params(axis='x', nbins=4)
plt.locator_params(axis='y', nbins=4)
plt.xlabel('',fontsize=16)
plt.ylabel('Poised:Active\nEnhancer Ratio',fontsize=20)
# plt.legend(title='Peak-Gene Pairs Prioritized by',title_fontsize=18,fontsize=16,frameon=False,bbox_to_anchor=(1,1),handlelength=0.8)
# g.axhline(y=all_ratio,linestyle='--',color='black',linewidth=3)

sns.despine()

plot_dir = '/data/cb/alexwu/mm_finemap/figures'
plt.savefig(os.path.join(plot_dir,'gridnet_vs_corr','poised_vs_active.corr.0324.png'.format(dataset)), dpi=500, bbox_inches = "tight")
plt.show()

# %%
plt.figure(figsize=(1.7,3))
g = sns.barplot(x='placement',y='ratio',data=results_df[results_df["method"] == "GrID-Net\nvs.\nPseudocell Corr"],palette='Paired')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.locator_params(axis='x', nbins=4)
plt.locator_params(axis='y', nbins=4)
plt.xlabel('',fontsize=16)
plt.ylabel('Poised:Active\nEnhancer Ratio',fontsize=20)
# plt.legend(title='Peak-Gene Pairs Prioritized by',title_fontsize=18,fontsize=16,frameon=False,bbox_to_anchor=(1,1),handlelength=0.8)
# g.axhline(y=all_ratio,linestyle='--',color='black',linewidth=3)

sns.despine()

plot_dir = '/data/cb/alexwu/mm_finemap/figures'
plt.savefig(os.path.join(plot_dir,'gridnet_vs_corr','poised_vs_active.pseudocell_corr.0324.png'.format(dataset)), dpi=500, bbox_inches = "tight")
plt.show()

# %%
results_df
# Out:
#                            method          placement     ratio
# 0      GrID-Net\nvs.\nCorrelation           GrID-Net  0.295983
# 1      GrID-Net\nvs.\nCorrelation  Corr-Based Method  0.189931
# 3  GrID-Net\nvs.\nPseudocell Corr           GrID-Net  0.264753
# 4  GrID-Net\nvs.\nPseudocell Corr  Corr-Based Method  0.208602

# %% [markdown]
# ### Pseudotime @ Max Value

# %%
# create metacells
sc.pp.neighbors(rna_adata,n_neighbors=50,use_rep='X_schema')
group_rna_adata,group_atac_adata = create_metacells(rna_adata,atac_adata)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000

# %%
sc.pp.neighbors(rna_adata,use_rep='X_schema',n_neighbors=15)
sc.tl.dpt(rna_adata)

# %%
gene_max_dpt_dict = {g: rna_adata.obs['dpt_pseudotime'].values[idx] for g,idx in 
                zip(*[rna_adata.var.index.values,np.array(np.argmax(group_rna_adata.X,axis=0)).squeeze()])}
peak_max_dpt_dict = {str(atac_id): rna_adata.obs['dpt_pseudotime'].values[idx] for atac_id,idx in 
                zip(*[atac_adata.var.index.values,np.array(np.argmax(group_atac_adata.X,axis=0)).squeeze()])}

# %% [markdown]
# #### Pseudocell Correlation Ranks

# %%
eval_df['corr_diff'] = eval_df['graph.ranks.mean']-eval_df['corr.ranks.mean']
eval_df['group_corr_diff'] = eval_df['graph.ranks.mean']-eval_df['group_corr.ranks.mean']

compare_key = 'group_corr_diff'

thresh = np.percentile(eval_df[compare_key],99)
diff_top_dpt_diff = []
top_gene_max_dpt_list = []
top_peak_max_dpt_list = []
for g,atac_id in eval_df[(eval_df[compare_key] > thresh)][['gene','atac_id']].values:
    g = g.decode('utf-8')
    gene_max_dpt = gene_max_dpt_dict[g]
    peak_max_dpt = peak_max_dpt_dict[str(atac_id)]
    diff_top_dpt_diff.append(gene_max_dpt-peak_max_dpt)
    top_gene_max_dpt_list.append(gene_max_dpt)
    top_peak_max_dpt_list.append(peak_max_dpt)
    
diff_top_dpt_diff = np.array(diff_top_dpt_diff)

thresh = np.percentile(eval_df[compare_key],1)
diff_bottom_dpt_diff = []
bottom_gene_max_dpt_list = []
bottom_peak_max_dpt_list = []
for g,atac_id in eval_df[(eval_df[compare_key] < thresh)][['gene','atac_id']].values:
    g = g.decode('utf-8')
    gene_max_dpt = gene_max_dpt_dict[g]
    peak_max_dpt = peak_max_dpt_dict[str(atac_id)]
    diff_bottom_dpt_diff.append(gene_max_dpt-peak_max_dpt)
    bottom_gene_max_dpt_list.append(gene_max_dpt)
    bottom_peak_max_dpt_list.append(peak_max_dpt)
    
diff_bottom_dpt_diff = np.array(diff_bottom_dpt_diff)

# remove outliers
top_gene_max_dpt = np.array(top_gene_max_dpt_list)[abs(diff_top_dpt_diff) < 0.5]
top_peak_max_dpt = np.array(top_peak_max_dpt_list)[abs(diff_top_dpt_diff) < 0.5]

bottom_gene_max_dpt = np.array(bottom_gene_max_dpt_list)[abs(diff_bottom_dpt_diff) < 0.5]
bottom_peak_max_dpt = np.array(bottom_peak_max_dpt_list)[abs(diff_bottom_dpt_diff) < 0.5]

diff_top_dpt_diff = abs(diff_top_dpt_diff[abs(diff_top_dpt_diff) < 0.5])
diff_bottom_dpt_diff = abs(diff_bottom_dpt_diff[abs(diff_bottom_dpt_diff) < 0.5])

# %%
plt.scatter(top_gene_max_dpt,top_peak_max_dpt,s=5,alpha=0.5)
# plt.plot()
plt.show()

# %%
data_dict = {k: [] for k in ['value','placement']}
data_dict['value'].extend(diff_top_dpt_diff)
data_dict['placement'].extend(['Top\n1%']*len(diff_top_dpt_diff))

data_dict['value'].extend(diff_bottom_dpt_diff)
data_dict['placement'].extend(['Bottom\n1%']*len(diff_bottom_dpt_diff))

plot_df = pd.DataFrame(data_dict)

plt.figure(figsize=(1.7,3))
sns.barplot(x='placement',y='value',data=plot_df,palette=sns.color_palette('Paired')[4:],capsize=0.1,errwidth=2)

plt.xlabel('')
plt.ylabel('Pseudotime Lag',fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.locator_params(axis='x', nbins=4)
plt.locator_params(axis='y', nbins=4)
plt.xlabel('Peak-Gene Pairs',fontsize=16) #  \n(GrID-Net vs. Pseudocell\nCorrelation)',fontsize=16)
sns.despine()

plot_dir = '/data/cb/alexwu/mm_finemap/figures'
plt.savefig(os.path.join(plot_dir,'gridnet_vs_corr','pseudotime_lag.bar.0324.png'.format(dataset)), dpi=500, bbox_inches = "tight")

plt.show()

# %%
from scipy.stats import ttest_ind

ttest_ind(plot_df[plot_df['placement'] == 'Top\n1%']['value'],
          plot_df[plot_df['placement'] == 'Bottom\n1%']['value'],equal_var=False,alternative='greater')
# Out:
# Ttest_indResult(statistic=10.841558040538523, pvalue=1.237276826459529e-27)

# %% [markdown]
# #### Pearson Correlation Ranks

# %%
eval_df['corr_diff'] = eval_df['graph.ranks.mean']-eval_df['corr.ranks.mean']
eval_df['group_corr_diff'] = eval_df['graph.ranks.mean']-eval_df['group_corr.ranks.mean']

compare_key = 'corr_diff'

thresh = np.percentile(eval_df[compare_key],99)
diff_top_dpt_diff = []
for g,atac_id in eval_df[(eval_df[compare_key] > thresh)][['gene','atac_id']].values:
    g = g.decode('utf-8')
    gene_max_dpt = gene_max_dpt_dict[g]
    peak_max_dpt = peak_max_dpt_dict[str(atac_id)]
    diff_top_dpt_diff.append(gene_max_dpt-peak_max_dpt)
diff_top_dpt_diff = np.array(diff_top_dpt_diff)

thresh = np.percentile(eval_df[compare_key],1)
diff_bottom_dpt_diff = []
for g,atac_id in eval_df[(eval_df[compare_key] < thresh)][['gene','atac_id']].values:
    g = g.decode('utf-8')
    gene_max_dpt = gene_max_dpt_dict[g]
    peak_max_dpt = peak_max_dpt_dict[str(atac_id)]
    diff_bottom_dpt_diff.append(gene_max_dpt-peak_max_dpt)
diff_bottom_dpt_diff = np.array(diff_bottom_dpt_diff)

# remove outliers
diff_top_dpt_diff = abs(diff_top_dpt_diff[abs(diff_top_dpt_diff) < 0.5])
diff_bottom_dpt_diff = abs(diff_bottom_dpt_diff[abs(diff_bottom_dpt_diff) < 0.5])

# %%
data_dict = {k: [] for k in ['value','placement']}
data_dict['value'].extend(diff_top_dpt_diff)
data_dict['placement'].extend(['Top\n1%']*len(diff_top_dpt_diff))

data_dict['value'].extend(diff_bottom_dpt_diff)
data_dict['placement'].extend(['Bottom\n1%']*len(diff_bottom_dpt_diff))

plot_df = pd.DataFrame(data_dict)

plt.figure(figsize=(1.7,3))
sns.barplot(x='placement',y='value',data=plot_df,palette=sns.color_palette('Paired')[4:],capsize=0.1,errwidth=2)

plt.xlabel('')
plt.ylabel('Pseudotime Lag',fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.locator_params(axis='x', nbins=4)
plt.locator_params(axis='y', nbins=4)
plt.xlabel('Peak-Gene Pairs',fontsize=16) #  \n(GrID-Net vs. Pseudocell\nCorrelation)',fontsize=16)
sns.despine()

plot_dir = '/data/cb/alexwu/mm_finemap/figures'
plt.savefig(os.path.join(plot_dir,'gridnet_vs_corr','pseudotime_lag.corr.bar.0324.png'.format(dataset)), dpi=500, bbox_inches = "tight")

plt.show()

# %%
from scipy.stats import ttest_ind

ttest_ind(plot_df[plot_df['placement'] == 'Top\n1%']['value'],
          plot_df[plot_df['placement'] == 'Bottom\n1%']['value'],equal_var=False,alternative='greater')
# Out:
# Ttest_indResult(statistic=13.728019613483548, pvalue=4.7246211908045935e-43)

# %% [markdown]
# ## Gene Set Enrichment

# %%
eval_df['corr_diff'] = eval_df['graph.ranks.mean']-eval_df['corr.ranks.mean']
eval_df['group_corr_diff'] = eval_df['graph.ranks.mean']-eval_df['group_corr.ranks.mean']
eval_df['corr_sum'] = eval_df['graph.ranks.mean'].values+eval_df['corr.ranks.mean'].values
eval_df['group_corr_sum'] = eval_df['graph.ranks.mean'].values+eval_df['group_corr.ranks.mean'].values

# %% [markdown]
# ### GSEA Pre-rank

# %%
import gseapy as gp

genesets2use = ['GO_Biological_Process_2021','GO_Molecular_Function_2021',
                'GO_Cellular_Component_2021','Reactome_2016','CellMarker_Augmented_2021',
                'Jensen_TISSUES','KEGG_2021_Human']

for score_key in ['corr_sum','group_corr_sum']: #['corr_diff','group_corr_diff']:
    sorted_genes = eval_df.sort_values(score_key,ascending=False)['gene'].drop_duplicates().values

    save_dir = '/data/cb/alexwu/mm_finemap/results/enrichment'

    rnk = pd.DataFrame(sorted_genes)
    rnk[1] = rnk.shape[0]-np.arange(rnk.shape[0])

    for gene_set in genesets2use:
        print(score_key,gene_set)
        pre_res = gp.prerank(rnk=rnk, gene_sets=gene_set,processes=8,
                             outdir=os.path.join(save_dir,'gsea_prerank_{}_{}'.format(gene_set,score_key)), seed=1)
# Out:
# group_corr_sum GO_Biological_Process_2021

# %%
save_dir = '/data/cb/alexwu/mm_finemap/results/enrichment'

genesets2use = ['GO_Biological_Process_2021','GO_Molecular_Function_2021',
                'GO_Cellular_Component_2021','Reactome_2016','CellMarker_Augmented_2021',
                'Jensen_TISSUES','KEGG_2021_Human']
    
results_df_list = []

for score_key in ['corr_diff','group_corr_diff']:
    for gene_set in genesets2use:

        file_path = os.path.join(save_dir,'gsea_prerank_{}_{}'.format(gene_set,score_key),'gseapy.prerank.gene_sets.report.csv')
        if os.path.exists(file_path):
            results_df = pd.read_csv(file_path)
            results_df['gene_set'] = gene_set
            results_df['score_key'] = score_key
            results_df_list.append(results_df)

results_df = pd.concat(results_df_list)
results_df = results_df[results_df['fdr'] < 0.01]

# %%
from collections import Counter

for n,c in Counter(results_df[results_df['es'] < 0]['Term']).most_common():
    if c == 2:
        print(n)
# Out:
# Golgi to plasma membrane transport (GO:0006893)
# SRP-dependent cotranslational protein targeting to membrane (GO:0006614)
# cotranslational protein targeting to membrane (GO:0006613)
# cytoplasmic translation (GO:0002181)
# negative regulation of cell cycle G2/M phase transition (GO:1902750)
# nuclear-transcribed mRNA catabolic process (GO:0000956)
# nuclear-transcribed mRNA catabolic process, nonsense-mediated decay (GO:0000184)
# positive regulation of TOR signaling (GO:0032008)
# regulation of alternative mRNA splicing, via spliceosome (GO:0000381)
# regulation of cellular amine metabolic process (GO:0033238)
# regulation of cellular amino acid metabolic process (GO:0006521)
# regulation of mRNA processing (GO:0050684)
# regulation of mRNA splicing, via spliceosome (GO:0048024)
# regulation of neurogenesis (GO:0050767)
# spliceosomal complex assembly (GO:0000245)
# mitochondrial proton-transporting ATP synthase complex (GO:0005753)
# polysomal ribosome (GO:0042788)
# proton-transporting ATP synthase complex (GO:0045259)
# Formation of the ternary complex, and subsequently, the 43S complex Homo sapiens R-HSA-72695
# Translation initiation complex formation Homo sapiens R-HSA-72649
# 3' -UTR-mediated translational regulation Homo sapiens R-HSA-157279
# APC/C:Cdc20 mediated degradation of Securin Homo sapiens R-HSA-174154
# AUF1 (hnRNP D0) binds and destabilizes mRNA Homo sapiens R-HSA-450408
# Activation of the mRNA upon binding of the cap-binding complex and eIFs, and subsequent binding to 43S Homo sapiens R-HSA-72662
# Autodegradation of the E3 ubiquitin ligase COP1 Homo sapiens R-HSA-349425
# Cap-dependent Translation Initiation Homo sapiens R-HSA-72737
# Circadian Clock Homo sapiens R-HSA-400253
# Cross-presentation of soluble exogenous antigens (endosomes) Homo sapiens R-HSA-1236978
# Degradation of GLI1 by the proteasome Homo sapiens R-HSA-5610780
# Degradation of GLI2 by the proteasome Homo sapiens R-HSA-5610783
# Eukaryotic Translation Elongation Homo sapiens R-HSA-156842
# Eukaryotic Translation Initiation Homo sapiens R-HSA-72613
# Eukaryotic Translation Termination Homo sapiens R-HSA-72764
# Fcgamma receptor (FCGR) dependent phagocytosis Homo sapiens R-HSA-2029480
# Formation of a pool of free 40S subunits Homo sapiens R-HSA-72689
# GLI3 is processed to GLI3R by the proteasome Homo sapiens R-HSA-5610785
# GTP hydrolysis and joining of the 60S ribosomal subunit Homo sapiens R-HSA-72706
# Hedgehog 'on' state Homo sapiens R-HSA-5632684
# Hedgehog ligand biogenesis Homo sapiens R-HSA-5358346
# Hh mutants abrogate ligand secretion Homo sapiens R-HSA-5387390
# Hh mutants that don't undergo autocatalytic processing are degraded by ERAD Homo sapiens R-HSA-5362768
# L13a-mediated translational silencing of Ceruloplasmin expression Homo sapiens R-HSA-156827
# Nonsense Mediated Decay (NMD) enhanced by the Exon Junction Complex (EJC) Homo sapiens R-HSA-975957
# Nonsense Mediated Decay (NMD) independent of the Exon Junction Complex (EJC) Homo sapiens R-HSA-975956
# Nonsense-Mediated Decay (NMD) Homo sapiens R-HSA-927802
# Peptide chain elongation Homo sapiens R-HSA-156902
# Regulation of actin dynamics for phagocytic cup formation Homo sapiens R-HSA-2029482
# Regulation of activated PAK-2p34 by proteasome mediated degradation Homo sapiens R-HSA-211733
# Ribosomal scanning and start codon recognition Homo sapiens R-HSA-72702
# SRP-dependent cotranslational protein targeting to membrane Homo sapiens R-HSA-1799339
# Selenoamino acid metabolism Homo sapiens R-HSA-2408522
# Selenocysteine synthesis Homo sapiens R-HSA-2408557
# The role of GTSE1 in G2/M progression after G2 checkpoint Homo sapiens R-HSA-8852276
# Translation Homo sapiens R-HSA-72766
# Vif-mediated degradation of APOBEC3G Homo sapiens R-HSA-180585
# Viral mRNA Translation Homo sapiens R-HSA-192823
# Vpu mediated degradation of CD4 Homo sapiens R-HSA-180534
# Cancer Stem cell:Kidney
# Cardiomyocyte:Undefined
# Chromaffin cell:Adrenal Gland
# Clara cell:Undefined
# Definitive Zone cell:Adrenal Gland
# Esophageal Mucosal cell:Esophagus
# Intestinal Stem cell:Colon
# Intestinal Stem cell:Esophagus
# Intestinal Stem cell:Intestine
# Lake Et al.Science.Ex7:Brain
# Lake Et al.Science.In1:Brain
# Natural Killer cell:Breast
# Neuron:Spinal Cord
# Neuronal Progenitor cell:Undefined
# Osteogenic Precursor-Like cell:Dermis
# Small Intestinal Stem cell:Small Intestinal Crypt
# Platelet:Blood
# Brain cortex cell line
# Interstitial cell of Cajal
# mRNA surveillance pathway

# %%
0.0000001
# Out:
# 1e-07

# %%
inds2keep = [i for i,n in enumerate(results_df['Term']) if 'brain' in n.lower() or 'neur' in n.lower()]
results_df.iloc[inds2keep]
# Out:
#                                        Term        es       nes      pval  \
# 20  regulation of neurogenesis (GO:0050767) -0.143851       inf       NaN
# 9              Lake Et al.Science.Ex7:Brain -0.137315       inf       NaN
# 10             Lake Et al.Science.In1:Brain -0.144204       inf       NaN
# 12                       Neuron:Spinal Cord -0.226637       inf       NaN
# 13       Neuronal Progenitor cell:Undefined -0.149423       inf       NaN
# 21              Neural Crest cell:Undefined  0.668655  1.878828  0.000000
# 72                   Cancer Stem cell:Brain  0.550207  1.671194  0.002010
# 73              Cancer Stem-Like cell:Brain  0.590709  1.667565  0.005139
# 0                    Brain cortex cell line -0.153136       inf       NaN
# 18  regulation of neurogenesis (GO:0050767) -0.215083       inf       NaN
# 6                 Immature neuron:Undefined -0.078404       inf       NaN
# 10             Lake Et al.Science.Ex3:Brain -0.088786       inf       NaN
# 11             Lake Et al.Science.Ex7:Brain -0.146560       inf       NaN
# 12             Lake Et al.Science.In1:Brain -0.141349       inf       NaN
# 14                       Neuron:Spinal Cord -0.228660       inf       NaN
# 15       Neuronal Progenitor cell:Undefined -0.165410       inf       NaN
# 19              Neural Crest cell:Undefined  0.710125  2.008988  0.000000
# 0                    Brain cortex cell line -0.138682       inf       NaN
#
#          fdr  geneset_size  matched_size  \
# 20  0.000000            62            41
# 9   0.000000           100            86
# 10  0.000000            98            86
# 12  0.000000           100            96
# 13  0.000000           101            97
# 21  0.000566            22            15
# 72  0.005697            30            24
# 73  0.005837           100            15
# 0   0.000000           211           189
# 18  0.000000            62            41
# 6   0.000000           101            97
# 10  0.000000           102            91
# 11  0.000000           100            86
# 12  0.000000            98            86
# 14  0.000000           100            96
# 15  0.000000           101            97
# 19  0.000053            22            15
# 0   0.000000           211           189
#
#                                                 genes  \
# 20  HES7;BHLHE40;ARNTL;GPER1;NUMBL;WNT7A;HEY1;MME;...
# 9   PCDH18;TRIL;ANK2;CXCL12;BRINP1;PTPN5;TMEM200C;...
# 10  ST8SIA3;SOX1;CNTN2;PTPN5;KCNA2;XKR7;ZDHHC22;LR...
# 12  PCDHB4;PCDHB10;STK32A;EFNB3;ANK2;PCDHB14;BRINP...
# 13  SCRT1;ST8SIA3;SOX1;CNTN2;EFNB3;SLITRK1;AQP4;TM...
# 21  CSPG4;ITGA4;SNAI2;NEUROG1;SOX10;NEUROG2;NOTCH1...
# 72  FUT4;SCAMP3;CLCC1;CD44;BMI1;CADM1;MSI1;THY1;NF...
# 73  TEK;FUT4;IRAK3;CALCRL;NOTCH4;MMRN2;PCDH12;DAB2...
# 0   CRYM;ACAT1;IRGQ;ITPA;PSMC2;HBG1;ECHS1;OXCT1;PR...
# 18  NUMBL;OPRM1;BHLHE40;GPER1;MME;WNT7A;HES7;PRUNE...
# 6   ST8SIA3;HPCA;SCRT1;TMEM145;SLITRK1;NEUROD1;TME...
# 10  SYNPR;CNTN2;VWC2;TRPM3;SCN1A;KCNA2;HMGCLL1;PTP...
# 11  PCDH18;CXCL12;TRIL;TMEM200C;DAAM2;ANK2;BRINP1;...
# 12  ST8SIA3;SOX1;CNTN2;KCNA2;PTPN5;BEND5;ZDHHC22;X...
# 14  PCDHB10;PCDHB4;EFNB3;STK32A;ANK2;BRINP1;PCDHB1...
# 15  ST8SIA3;SCRT1;SOX1;CNTN2;SLITRK1;EFNB3;TMEM179...
# 19  CSPG4;SNAI2;ITGA4;NEUROG2;SOX10;NEUROG1;NUMB;N...
# 0   ACAT1;HBG1;PSMC2;ECHS1;ITPA;IRGQ;OXCT1;SGTA;CR...
#
#                                           ledge_genes  \
# 20  ARNTL;GPER1;NUMBL;WNT7A;HEY1;MME;LIG4;PRUNE1;O...
# 9   ADCYAP1R1;OLFM1;MAP1B;NFASC;ZNF536;DCLK1;TUB;T...
# 10  MGAT3;CTNND2;ADGRA1;LRRC55;NEFL;FXYD6;KCNC1;RA...
# 12  RBFOX2;ATP9A;MAP1B;NFASC;DCLK1;PCLO;PLPPR5;PSD...
# 13  CTNND2;ADGRA1;MAP2;BSN;KCNC1;SOX21;TUBB2B;CELF...
# 21            CSPG4;ITGA4;SNAI2;NEUROG1;SOX10;NEUROG2
# 72                        FUT4;SCAMP3;CLCC1;CD44;BMI1
# 73  TEK;FUT4;IRAK3;CALCRL;NOTCH4;MMRN2;PCDH12;DAB2...
# 0   ARHGDIA;RUVBL1;UQCRC1;RHOB;PCBP1;FSCN1;ENO2;CA...
# 18  NUMBL;OPRM1;BHLHE40;GPER1;MME;WNT7A;HES7;PRUNE...
# 6   CACNG7;GABRG2;SLC8A2;CAMK2N2;VGF;SLC12A5;KCNC1...
# 10  CNTN2;VWC2;TRPM3;SCN1A;KCNA2;HMGCLL1;PTPN5;FRR...
# 11  PCDH18;CXCL12;TRIL;TMEM200C;DAAM2;ANK2;BRINP1;...
# 12  PTPN5;BEND5;ZDHHC22;XKR7;LRRTM1;SHISA6;CTNND2;...
# 14  MAP2;NFASC;DCLK1;MAP1B;DCLK2;DIP2C;RBFOX2;SHC3...
# 15  CACNG7;SLC8A2;ADGRA1;KCNC1;BSN;SOX21;NOL4;TUBB...
# 19            CSPG4;SNAI2;ITGA4;NEUROG2;SOX10;NEUROG1
# 0   RHOB;FSCN1;RUVBL1;HBG2;GLOD4;ENO2;NDUFS1;CALM1...
#
#                       gene_set        score_key
# 20  GO_Biological_Process_2021        corr_diff
# 9    CellMarker_Augmented_2021        corr_diff
# 10   CellMarker_Augmented_2021        corr_diff
# 12   CellMarker_Augmented_2021        corr_diff
# 13   CellMarker_Augmented_2021        corr_diff
# 21   CellMarker_Augmented_2021        corr_diff
# 72   CellMarker_Augmented_2021        corr_diff
# 73   CellMarker_Augmented_2021        corr_diff
# 0               Jensen_TISSUES        corr_diff
# 18  GO_Biological_Process_2021  group_corr_diff
# 6    CellMarker_Augmented_2021  group_corr_diff
# 10   CellMarker_Augmented_2021  group_corr_diff
# 11   CellMarker_Augmented_2021  group_corr_diff
# 12   CellMarker_Augmented_2021  group_corr_diff
# 14   CellMarker_Augmented_2021  group_corr_diff
# 15   CellMarker_Augmented_2021  group_corr_diff
# 19   CellMarker_Augmented_2021  group_corr_diff
# 0               Jensen_TISSUES  group_corr_diff

# %%
save_dir = '/data/cb/alexwu/mm_finemap/results/enrichment'

genesets2use = ['GO_Biological_Process_2021','GO_Molecular_Function_2021',
                'GO_Cellular_Component_2021','Reactome_2016','CellMarker_Augmented_2021',
                'Jensen_TISSUES','KEGG_2021_Human']
    
results_df_list = []

for score_key in ['corr_sum','group_corr_sum']:
    for gene_set in genesets2use:

        file_path = os.path.join(save_dir,'gsea_prerank_{}_{}'.format(gene_set,score_key),'gseapy.prerank.gene_sets.report.csv')
        if os.path.exists(file_path):
            results_df = pd.read_csv(file_path)
            results_df['gene_set'] = gene_set
            results_df['score_key'] = score_key
            results_df_list.append(results_df)

results_df = pd.concat(results_df_list)
results_df = results_df[results_df['fdr'] < 0.01]

# %%
results_df
# Out:
#                                                  Term        es       nes  \
# 0         cellular response to chemokine (GO:1990869)  0.733648  2.115239
# 1   Fc receptor mediated stimulatory signaling pat... -0.154064       inf
# 2   Fc-gamma receptor signaling pathway involved i... -0.194255       inf
# 3     Golgi to plasma membrane transport (GO:0006893) -0.196981       inf
# 4   SRP-dependent cotranslational protein targetin... -0.280948       inf
# 5   cotranslational protein targeting to membrane ... -0.219728       inf
# 6                cytoplasmic translation (GO:0002181) -0.210879       inf
# 7   mitochondrial electron transport, NADH to ubiq... -0.185021       inf
# 8   nuclear-transcribed mRNA catabolic process (GO... -0.173899       inf
# 9   nuclear-transcribed mRNA catabolic process, no... -0.296120       inf
# 10  positive regulation of macroautophagy (GO:0016... -0.170016       inf
# 11  regulation of alternative mRNA splicing, via s... -0.114307       inf
# 12  regulation of mRNA splicing, via spliceosome (... -0.079054       inf
# 13    ribonucleoprotein complex assembly (GO:0022618) -0.130959       inf
# 14                granulocyte chemotaxis (GO:0071621)  0.703898  2.076593
# 15                 neutrophil chemotaxis (GO:0030593)  0.692048  2.009851
# 16      regulation of calcium ion import (GO:0090279)  0.673824  1.978627
# 17   purine nucleotide metabolic process (GO:0006163)  0.687513  1.972828
# 18  regulation of humoral immune response (GO:0002...  0.681581  1.928533
# 19  regulation of cardiac muscle cell contraction ...  0.631351  1.920697
# 20   regulation of complement activation (GO:0030449)  0.664509  1.896623
# 21  regulation of immune effector process (GO:0002...  0.674327  1.876124
# 22                  neutrophil migration (GO:1990266)  0.636457  1.866979
# 0            double-stranded RNA binding (GO:0003725) -0.168207       inf
# 0         cellular response to chemokine (GO:1990869)  0.760697  2.171251
# 1     Golgi to plasma membrane transport (GO:0006893) -0.258407       inf
# 2                  RNA 3'-end processing (GO:0031123) -0.147324       inf
# 3                         RNA processing (GO:0006396) -0.115063       inf
# 4                           RNA splicing (GO:0008380) -0.125296       inf
# 5   SRP-dependent cotranslational protein targetin... -0.312454       inf
# 6   cotranslational protein targeting to membrane ... -0.245883       inf
# 7                cytoplasmic translation (GO:0002181) -0.319719       inf
# 8   establishment of protein localization to plasm... -0.207597       inf
# 9                 mRNA 3'-end processing (GO:0031124) -0.135447       inf
# 10                mRNA metabolic process (GO:0016071) -0.147981       inf
# 11  mitotic nuclear membrane organization (GO:0101... -0.131108       inf
# 12   mitotic nuclear membrane reassembly (GO:0007084) -0.131108       inf
# 13           nuclear membrane reassembly (GO:0031468) -0.131138       inf
# 14  nuclear-transcribed mRNA catabolic process (GO... -0.157290       inf
# 15  nuclear-transcribed mRNA catabolic process, no... -0.251242       inf
# 16  positive regulation of telomere maintenance vi... -0.155792       inf
# 17  positive regulation of telomere maintenance vi... -0.155827       inf
# 18            regulation of RNA splicing (GO:0043484) -0.125936       inf
# 19  regulation of cellular amino acid metabolic pr... -0.122614       inf
# 20  regulation of telomere maintenance via telomer... -0.172814       inf
# 21    ribonucleoprotein complex assembly (GO:0022618) -0.179005       inf
# 22         spliceosomal complex assembly (GO:0000245) -0.180715       inf
# 23          endothelial cell development (GO:0001885)  0.717917  2.013545
# 24  phospholipase C-activating G protein-coupled r...  0.638620  1.961326
# 25      regulation of calcium ion import (GO:0090279)  0.665680  1.949439
# 26                granulocyte chemotaxis (GO:0071621)  0.655615  1.931154
# 27  regulation of humoral immune response (GO:0002...  0.654517  1.863519
# 28  regulation of transcription involved in G1/S t...  0.604446  1.859890
# 29                 neutrophil chemotaxis (GO:0030593)  0.634089  1.845289
# 30   regulation of complement activation (GO:0030449)  0.633140  1.825826
#
#         pval       fdr  geneset_size  matched_size  \
# 0   0.000000  0.000000            60            17
# 1        NaN  0.000000            74            58
# 2        NaN  0.000000            71            57
# 3        NaN  0.000000            48            43
# 4        NaN  0.000000            90            85
# 5        NaN  0.000000            94            89
# 6        NaN  0.000000            93            87
# 7        NaN  0.000000            39            37
# 8        NaN  0.000000           171           160
# 9        NaN  0.000000           113           106
# 10       NaN  0.000000            53            43
# 11       NaN  0.000000            54            50
# 12       NaN  0.000000            90            82
# 13       NaN  0.000000           136           124
# 14  0.000000  0.000258            73            20
# 15  0.000000  0.000604            70            18
# 16  0.000000  0.000796            25            19
# 17  0.000000  0.001020            24            16
# 18  0.000000  0.002595            54            16
# 19  0.000000  0.002658            27            23
# 20  0.001026  0.004189            50            16
# 21  0.001029  0.006151            53            15
# 22  0.001013  0.006556            77            19
# 0        NaN  0.000000            73            55
# 0   0.000000  0.000000            60            17
# 1        NaN  0.000000            48            43
# 2        NaN  0.000000            69            64
# 3        NaN  0.000000           179           165
# 4        NaN  0.000000            98            93
# 5        NaN  0.000000            90            85
# 6        NaN  0.000000            94            89
# 7        NaN  0.000000            93            87
# 8        NaN  0.000000            36            33
# 9        NaN  0.000000            79            74
# 10       NaN  0.000000            95            87
# 11       NaN  0.000000            51            49
# 12       NaN  0.000000            51            49
# 13       NaN  0.000000            54            52
# 14       NaN  0.000000           171           160
# 15       NaN  0.000000           113           106
# 16       NaN  0.000000            33            32
# 17       NaN  0.000000            36            35
# 18       NaN  0.000000            76            63
# 19       NaN  0.000000            54            47
# 20       NaN  0.000000            52            50
# 21       NaN  0.000000           136           124
# 22       NaN  0.000000            46            43
# 23  0.000000  0.000487            26            16
# 24  0.000000  0.001325            81            25
# 25  0.000000  0.001386            25            19
# 26  0.000000  0.001768            73            20
# 27  0.000000  0.005462            54            16
# 28  0.000000  0.005844            32            27
# 29  0.000000  0.007111            70            18
# 30  0.000000  0.009426            50            16
#
#                                                 genes  \
# 0   CCL3L1;CCL4;CCL3;DOCK8;CXCL13;SH2B3;CXCL12;PTK...
# 1   ARPC4;NR4A3;PLA2G6;CD247;PLPP4;VAV3;WIPF1;MYO1...
# 2   ARPC4;PLA2G6;CD247;PLPP4;VAV3;WIPF1;MYO1C;MAPK...
# 3   GCC2;GOLGA7;BBS1;NSF;BLZF1;EXOC8;GOPC;RAB26;GG...
# 4   SRP54;SRP19;ZFAND2B;SRP68;SEC61A1;RPS13;RPLP1;...
# 5   SRP54;SSR1;SRPRA;SRP19;SRP68;SEC61A1;RPS13;RPL...
# 6   RWDD1;RPL22L1;RPL26L1;DRG1;DRG2;RPS13;RPLP1;ZC...
# 7   NDUFA2;NDUFB5;NDUFB3;NDUFA4;NDUFA5;NDUFB6;NDUF...
# 8   CNOT9;ERI1;MRTO4;SMG9;CNOT8;DCP1B;CNOT3;EXOSC9...
# 9   SMG9;DHX34;UPF1;PYM1;HELZ2;UPF2;SMG8;NCBP2;MAG...
# 10  DCN;CALCOCO2;PRKAA2;BAG3;FYCO1;RALB;PINK1;GPSM...
# 11  RBM11;FXR2;RBM24;ZBTB7A;RBM7;ZC3H10;SRSF12;RBM...
# 12  RBM11;U2AF2;C1QBP;FXR2;RBM24;PCBP4;ZBTB7A;CWC2...
# 13  MRPS7;ISY1;DDX23;MRPS11;NLE1;PPAN;SART1;RRP7A;...
# 14  CCL3L1;CCL4;CCL3;CXCL13;ANXA1;SRP54;LGALS3;PIP...
# 15  CCL3L1;CCL4;CCL3;CXCL13;SRP54;LGALS3;PIP5K1C;C...
# 16  CCL3;GRM6;STC1;EGF;CXCL12;LGALS3;SLC30A1;SPHK2...
# 17  PNP;NT5E;GDA;ITPA;NT5C;NUDT15;PPAT;ADSL;MTHFD1...
# 18  C3;CXCL13;CD55;CPB2;SUSD4;PROS1;C1QBP;C5;C2;SE...
# 19  PDE4D;SCN5A;STC1;PKP2;DSG2;ATP2A1;HCN4;PLN;ANK...
# 20  C3;CD55;CPB2;SUSD4;PROS1;C1QBP;C5;C2;SERPING1;...
# 21  C3;CD55;CPB2;SUSD4;PROS1;C1QBP;C5;C2;SERPING1;...
# 22  CCL3L1;CCL4;CCL3;CXCL13;SRP54;LGALS3;PIP5K1C;C...
# 0   APTX;RFTN1;DDX60;ZFR2;SUPV3L1;SIDT2;DHX33;DUS2...
# 0   CCL3L1;CCL4;CCL3;DOCK8;CXCL12;CXCL13;SH2B3;PTK...
# 1   NSF;GOPC;BBS1;GOLGA7;SYS1;EXOC6B;BLZF1;GCC2;AR...
# 2   THOC5;DHX38;DDX39A;THOC7;U2AF2;CPSF3;CPSF2;CDC...
# 3   RBMS2;WBP4;RBMS1;RNPC3;PPARGC1A;DDX23;LSM6;RP9...
# 4   WBP4;RNPC3;PPARGC1A;DDX23;LSM6;RP9;SNRNP35;USB...
# 5   SRP54;SRP19;SRP68;ZFAND2B;RPS13;RPLP1;SEC61A1;...
# 6   SRP54;SRPRA;SRP19;SSR1;SRP68;RPS13;RPLP1;SEC61...
# 7   RPL22L1;RPL26L1;RWDD1;RPS13;RPLP1;DRG1;DRG2;ZC...
# 8   RILPL2;NSF;BBS1;GOLGA7;SYS1;BLZF1;GCC2;ARFRP1;...
# 9   THOC5;DHX38;LSM11;DDX39A;THOC7;U2AF2;POLR2D;CP...
# 10  RNASE4;PPARGC1A;LSM6;PRKACA;SF3A1;LSM11;NUDT16...
# 11  VPS4A;RANGAP1;NUP35;NUP43;CHMP2A;REEP4;CHMP2B;...
# 12  VPS4A;RANGAP1;NUP35;NUP43;CHMP2A;REEP4;CHMP2B;...
# 13  VPS4A;RANGAP1;NUP35;NUP43;CHMP2A;REEP4;CHMP2B;...
# 14  ATM;EXOSC9;EXOSC8;CNOT9;CNOT8;EXOSC5;SMG9;UPF1...
# 15  SMG9;UPF1;UPF2;HELZ2;DHX34;NCBP2;PNRC2;RPS13;R...
# 16  ATM;PRKCQ;CCT8;FBXO4;MAPKAPK5;MAPK3;PKIB;NEK2;...
# 17  ATM;PRKCQ;CCT8;FBXO4;MAPKAPK5;MAPK3;PKIB;NEK2;...
# 18  AHNAK2;PTBP2;RBM20;ZPR1;U2AF2;CLK3;CLK2;RBM12;...
# 19  PSMC2;PSME2;PSMF1;PSMC4;NQO1;PSMB8;PSME3;PSMD6...
# 20  ATM;PRKCQ;STN1;CCT8;TINF2;TERF2;FBXO4;PINX1;NA...
# 21  MRPS7;DDX23;SART1;ISY1;CELF6;PRMT5;SF3A2;NLE1;...
# 22  DDX23;SF3A1;CELF6;SF3A2;PRPF19;NOL3;USP39;GCFC...
# 23  PDE4D;COL15A1;COL22A1;STC1;MYADM;GSTM3;MET;PPP...
# 24  GRM1;ADRA1B;ESR1;GNA14;P2RY12;HRH1;P2RY1;LPAR1...
# 25  CCL3;EGF;STC1;LGALS3;SPHK2;CXCL12;CCL2;PSEN2;P...
# 26  CCL3L1;CCL4;CCL3;ANXA1;SRP54;LGALS3;CXCL13;CCL...
# 27  C3;SUSD4;CD55;CXCL13;PROS1;C5;SERPING1;CPB2;C1...
# 28  E2F7;ORC1;CCNA1;CDC6;CDC45;E2F1;HINFP;FBXO5;NP...
# 29  CCL3L1;CCL4;CCL3;SRP54;LGALS3;CXCL13;CCL2;PIP5...
# 30  C3;SUSD4;CD55;PROS1;C5;SERPING1;CPB2;C1QBP;C1S...
#
#                                           ledge_genes  \
# 0   CCL3L1;CCL4;CCL3;DOCK8;CXCL13;SH2B3;CXCL12;PTK...
# 1   VAV3;WIPF1;MYO1C;MAPK3;PLD2;ARPC1B;LIMK1;ABI1;...
# 2   PLPP4;VAV3;WIPF1;MYO1C;MAPK3;PLD2;ARPC1B;LIMK1...
# 3   EXOC8;GOPC;RAB26;GGA3;RAB34;VAMP4;LLGL1;ARFRP1...
# 4   SRP19;ZFAND2B;SRP68;SEC61A1;RPS13;RPLP1;SRP72;...
# 5   SEC61A1;RPS13;RPLP1;SRP72;SEC63;SRP9;RPL12;SIL...
# 6   RPS13;RPLP1;ZC3H15;EIF3M;EIF3I;GSPT1;RPL12;ETF...
# 7   NDUFA3;NDUFA8;NDUFS4;NDUFAF1;NDUFV3;NDUFA10;ND...
# 8   DCP1B;CNOT3;EXOSC9;LSM1;EXOSC8;DCPS;EXOSC4;DHX...
# 9   DHX34;UPF1;PYM1;HELZ2;UPF2;SMG8;NCBP2;MAGOHB;P...
# 10  PINK1;GPSM1;IRGM;SESN2;SCOC;PIP4K2C;SMCR8;SIRT...
# 11  SAP18;NOVA2;CELF3;YTHDC1;RBFOX1;RBFOX2;MAGOH;C...
# 12  SAP18;NOVA2;CELF3;YTHDC1;RBFOX1;RBFOX2;SFSWAP;...
# 13  DDX23;MRPS11;NLE1;PPAN;SART1;RRP7A;DDX20;USP39...
# 14  CCL3L1;CCL4;CCL3;CXCL13;ANXA1;SRP54;LGALS3;PIP...
# 15  CCL3L1;CCL4;CCL3;CXCL13;SRP54;LGALS3;PIP5K1C;CCL2
# 16  CCL3;GRM6;STC1;EGF;CXCL12;LGALS3;SLC30A1;SPHK2...
# 17            PNP;NT5E;GDA;ITPA;NT5C;NUDT15;PPAT;ADSL
# 18  C3;CXCL13;CD55;CPB2;SUSD4;PROS1;C1QBP;C5;C2;SE...
# 19  PDE4D;SCN5A;STC1;PKP2;DSG2;ATP2A1;HCN4;PLN;ANK...
# 20  C3;CD55;CPB2;SUSD4;PROS1;C1QBP;C5;C2;SERPING1;C1S
# 21  C3;CD55;CPB2;SUSD4;PROS1;C1QBP;C5;C2;SERPING1;C1S
# 22  CCL3L1;CCL4;CCL3;CXCL13;SRP54;LGALS3;PIP5K1C;CCL2
# 0   APTX;RFTN1;DDX60;ZFR2;SUPV3L1;SIDT2;DHX33;DUS2...
# 0   CCL3L1;CCL4;CCL3;DOCK8;CXCL12;CXCL13;SH2B3;PTK...
# 1   SYS1;EXOC6B;BLZF1;GCC2;ARFRP1;PREPL;RAB34;STXB...
# 2   DDX39A;THOC7;U2AF2;CPSF3;CPSF2;CDC40;PCF11;NCB...
# 3   PPARGC1A;DDX23;LSM6;RP9;PRKACA;SF3A1;SNRNP35;S...
# 4   PPARGC1A;DDX23;LSM6;RP9;SNRNP35;USB1;CCAR2;PRP...
# 5   SRP68;ZFAND2B;RPS13;RPLP1;SEC61A1;SRP9;RPL38;S...
# 6   SRP9;RPL38;SEC63;RPL12;UBA52;RPS15A;SRP72;RPL1...
# 7   RPS13;RPLP1;DRG1;DRG2;ZC3H15;EIF3M;RPL38;RPL12...
# 8   BBS1;GOLGA7;SYS1;BLZF1;GCC2;ARFRP1;PREPL;RAB34...
# 9   LSM11;DDX39A;THOC7;U2AF2;POLR2D;CPSF3;CPSF2;CD...
# 10  PPARGC1A;LSM6;PRKACA;SF3A1;LSM11;NUDT16L1;SF3A...
# 11  VPS4A;RANGAP1;NUP35;NUP43;CHMP2A;REEP4;CHMP2B;...
# 12  VPS4A;RANGAP1;NUP35;NUP43;CHMP2A;REEP4;CHMP2B;...
# 13  VPS4A;RANGAP1;NUP35;NUP43;CHMP2A;REEP4;CHMP2B;...
# 14  ATM;EXOSC9;EXOSC8;CNOT9;CNOT8;EXOSC5;SMG9;UPF1...
# 15  RPS13;RPLP1;EIF3E;SKIV2L;SMG8;PYM1;CASC3;MAGOH...
# 16  ATM;PRKCQ;CCT8;FBXO4;MAPKAPK5;MAPK3;PKIB;NEK2;...
# 17  ATM;PRKCQ;CCT8;FBXO4;MAPKAPK5;MAPK3;PKIB;NEK2;...
# 18  ZPR1;U2AF2;CLK3;CLK2;RBM12;METTL4;RBM12B;AHNAK...
# 19  PSMD9;BCKDK;PSME1;PSMA5;OAZ2;PSMB10;PSMA1;PSMD...
# 20  STN1;CCT8;TINF2;TERF2;FBXO4;PINX1;NAT10;EXOSC1...
# 21  SART1;ISY1;CELF6;PRMT5;SF3A2;NLE1;MRPS11;PRPF1...
# 22  DDX23;SF3A1;CELF6;SF3A2;PRPF19;NOL3;USP39;GCFC...
# 23  PDE4D;COL15A1;COL22A1;STC1;MYADM;GSTM3;MET;PPP...
# 24  GRM1;ADRA1B;ESR1;GNA14;P2RY12;HRH1;P2RY1;LPAR1...
# 25  CCL3;EGF;STC1;LGALS3;SPHK2;CXCL12;CCL2;PSEN2;P...
# 26    CCL3L1;CCL4;CCL3;ANXA1;SRP54;LGALS3;CXCL13;CCL2
# 27  C3;SUSD4;CD55;CXCL13;PROS1;C5;SERPING1;CPB2;C1QBP
# 28  E2F7;ORC1;CCNA1;CDC6;CDC45;E2F1;HINFP;FBXO5;NP...
# 29          CCL3L1;CCL4;CCL3;SRP54;LGALS3;CXCL13;CCL2
# 30         C3;SUSD4;CD55;PROS1;C5;SERPING1;CPB2;C1QBP
#
#                       gene_set       score_key
# 0   GO_Biological_Process_2021        corr_sum
# 1   GO_Biological_Process_2021        corr_sum
# 2   GO_Biological_Process_2021        corr_sum
# 3   GO_Biological_Process_2021        corr_sum
# 4   GO_Biological_Process_2021        corr_sum
# 5   GO_Biological_Process_2021        corr_sum
# 6   GO_Biological_Process_2021        corr_sum
# 7   GO_Biological_Process_2021        corr_sum
# 8   GO_Biological_Process_2021        corr_sum
# 9   GO_Biological_Process_2021        corr_sum
# 10  GO_Biological_Process_2021        corr_sum
# 11  GO_Biological_Process_2021        corr_sum
# 12  GO_Biological_Process_2021        corr_sum
# 13  GO_Biological_Process_2021        corr_sum
# 14  GO_Biological_Process_2021        corr_sum
# 15  GO_Biological_Process_2021        corr_sum
# 16  GO_Biological_Process_2021        corr_sum
# 17  GO_Biological_Process_2021        corr_sum
# 18  GO_Biological_Process_2021        corr_sum
# 19  GO_Biological_Process_2021        corr_sum
# 20  GO_Biological_Process_2021        corr_sum
# 21  GO_Biological_Process_2021        corr_sum
# 22  GO_Biological_Process_2021        corr_sum
# 0   GO_Molecular_Function_2021        corr_sum
# 0   GO_Biological_Process_2021  group_corr_sum
# 1   GO_Biological_Process_2021  group_corr_sum
# 2   GO_Biological_Process_2021  group_corr_sum
# 3   GO_Biological_Process_2021  group_corr_sum
# 4   GO_Biological_Process_2021  group_corr_sum
# 5   GO_Biological_Process_2021  group_corr_sum
# 6   GO_Biological_Process_2021  group_corr_sum
# 7   GO_Biological_Process_2021  group_corr_sum
# 8   GO_Biological_Process_2021  group_corr_sum
# 9   GO_Biological_Process_2021  group_corr_sum
# 10  GO_Biological_Process_2021  group_corr_sum
# 11  GO_Biological_Process_2021  group_corr_sum
# 12  GO_Biological_Process_2021  group_corr_sum
# 13  GO_Biological_Process_2021  group_corr_sum
# 14  GO_Biological_Process_2021  group_corr_sum
# 15  GO_Biological_Process_2021  group_corr_sum
# 16  GO_Biological_Process_2021  group_corr_sum
# 17  GO_Biological_Process_2021  group_corr_sum
# 18  GO_Biological_Process_2021  group_corr_sum
# 19  GO_Biological_Process_2021  group_corr_sum
# 20  GO_Biological_Process_2021  group_corr_sum
# 21  GO_Biological_Process_2021  group_corr_sum
# 22  GO_Biological_Process_2021  group_corr_sum
# 23  GO_Biological_Process_2021  group_corr_sum
# 24  GO_Biological_Process_2021  group_corr_sum
# 25  GO_Biological_Process_2021  group_corr_sum
# 26  GO_Biological_Process_2021  group_corr_sum
# 27  GO_Biological_Process_2021  group_corr_sum
# 28  GO_Biological_Process_2021  group_corr_sum
# 29  GO_Biological_Process_2021  group_corr_sum
# 30  GO_Biological_Process_2021  group_corr_sum

# %%
inds2keep = [i for i,n in enumerate(results_df['Term']) if 'brain' in n.lower() or 'neur' in n.lower()]
results_df.iloc[inds2keep]
# Out:
# Empty DataFrame
# Columns: [Term, es, nes, pval, fdr, geneset_size, matched_size, genes, ledge_genes, gene_set, score_key]
# Index: []

# %% [markdown]
# ### Enrichr

# %%
import gseapy as gp

background_genes = list(set(eval_df['gene']))
outdir = '/data/cb/alexwu/mm_finemap/results/enrichment/gridnet_vs_corr'

for compare_key in ['corr_diff','group_corr_diff']:
    
    print(compare_key)
    
    thresh = np.percentile(eval_df[compare_key],99)
    diff_top_genes = list(set(eval_df[(eval_df[compare_key] > thresh)]['gene']))

    enr = gp.enrichr(gene_list=diff_top_genes,
                     gene_sets=genesets2use,
                     organism='Human',
                     description='test_name',
                     outdir=os.path.join(outdir,compare_key),
                     background=background_genes,
                     cutoff=0.05
                    )
    results_df = enr.results[enr.results['Adjusted P-value'] < 0.1]
    results_df.to_csv(os.path.join(outdir,'top.{}.enrichr.tsv'.format(compare_key)),
                      sep='\t',index=False)
                      
    thresh = np.percentile(eval_df[compare_key],1)
    diff_bottom_genes = list(set(eval_df[(eval_df[compare_key] < thresh)]['gene']))
    
    enr = gp.enrichr(gene_list=diff_bottom_genes,
                     gene_sets=genesets2use,
                     organism='Human',
                     description='test_name',
                     outdir=os.path.join(outdir,score_key),
                     background=background_genes,
                     cutoff=0.05
                    )
    results_df = enr.results[enr.results['Adjusted P-value'] < 0.1]
    results_df.to_csv(os.path.join(outdir,'bottom.{}.enrichr.tsv'.format(compare_key)),
                      sep='\t',index=False)
# Out:
# corr_diff
# 2022-05-30 21:50:56,711 Warning: No enrich terms using library GO_Biological_Process_2021 when cutoff = 0.05
# 2022-05-30 21:51:08,583 Warning: No enrich terms using library GO_Cellular_Component_2021 when cutoff = 0.05
# 2022-05-30 21:51:21,119 Warning: No enrich terms using library CellMarker_Augmented_2021 when cutoff = 0.05
# 2022-05-30 21:51:27,233 Warning: No enrich terms using library Jensen_TISSUES when cutoff = 0.05
# group_corr_diff
# 2022-05-30 21:52:17,830 Warning: No enrich terms using library GO_Biological_Process_2021 when cutoff = 0.05
# 2022-05-30 21:52:23,654 Warning: No enrich terms using library GO_Molecular_Function_2021 when cutoff = 0.05
# 2022-05-30 21:52:47,162 Warning: No enrich terms using library Jensen_TISSUES when cutoff = 0.05
